# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
from skimage import io

# %%
image = io.imread("https://pbs.twimg.com/profile_images/1503680672292081668/BFab2nla_400x400.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FBDFE2AD150>

# %%
gray_filter=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_filter)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBDEFF0C790>

# %%
inverted_filter=cv2.bitwise_not(gray_filter)
cv2_imshow(inverted_filter)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBDDB5C9350>

# %%
image_smoothing=cv2.GaussianBlur(inverted_filter,(21,21),sigmaX=0,sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBDDB5C9A10>

# %%
def pencil_sketch(x,y):
  return cv2.divide(x,255-y,scale=256)

# %%
pencil_sketch=pencil_sketch(gray_filter,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBDDB5D4810>

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7FBDDB5D4B10>
# <PIL.Image.Image image mode=L size=400x400 at 0x7FBDDB5D4BD0>
